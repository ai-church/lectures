# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn.manifold import TSNE

# %%
def prepare_data(funcs, noise):
    data = []
    for func in funcs:
        t = np.random.randn(100)
        x = np.stack([f(t) for f in func])
        x += np.random.randn(len(func), 100) * noise
        data.append(x)
    return np.concatenate(data, axis = 1)

# %%
def plot_TSNE(funcs, colors, noise):
    X = prepare_data(funcs, noise)
    print(X.shape)
    
    tsne = TSNE(n_components=2, perplexity=30, n_iter=300)
    X_tsne = tsne.fit_transform(X.T)
    #print(tsne.transform([[-3.3, -1.8, -1.8]]))
            
    # Visualisation
    all_colors = []
    for color in colors:
        all_colors += [color] * 100
    plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c = all_colors)
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.title("TSNE")
    plt.show()

# %%
plot_TSNE([
        [
            lambda x: 2 * x - 1.3,
            lambda x: 2 * x + 0.2,
            lambda x: 2 * x + 0.2,    # same
        ],
        [
            lambda x: 2 * x - 0.5,
            lambda x: -2 * x + 1.1,
            lambda x: -2 * x + 1.1,   # same
        ],
        [
            lambda x: 3 * x - 1.5,
            lambda x: -1.5 * x + 0.5,
            lambda x: -1.5 * x + 0.5, # same
        ]
    ],
    ['yellow', 'blue', 'green'],
    0.5,
)
# Out:
# (3, 300)

# %%
plot_TSNE([
        [
            lambda x: 2 * x - 1.3,
            lambda x: 2 * x + 0.2,
            lambda x: -3 * x + 0.2,
        ],
        [
            lambda x: 2 * x - 0.5,
            lambda x: -2 * x + 1.1,
            lambda x: 1.5 * x - 6.1,
        ],
        [
            lambda x: -3 * x - 1.5,
            lambda x: -1.5 * x + 0.5,
            lambda x: -2.7 * x - 0.2,
        ]
    ],
    ['yellow', 'blue', 'green'],
    0.5,
)
# Out:
# (3, 300)

# %%
plot_TSNE([
        [
            lambda x: 0 * x - 1.3,
            lambda x: 0 * x + 0.2,
            lambda x: 0 * x + 0.2,
        ],
        [
            lambda x: 0 * x - 0.5,
            lambda x: 0 * x + 1.1,
            lambda x: 0 * x - 6.1,
        ],
        [
            lambda x: 0 * x - 1.5,
            lambda x: 0 * x + 0.5,
            lambda x: 0 * x - 0.2,
        ]
    ],
    ['yellow', 'blue', 'green'],
    0.1,
)
# Out:
# (3, 300)
